# %%
# Dependencies
import pandas as pd
import requests
import json
import requests
import gmaps
import os
import requests
from pprint import pprint

# Google developer API key
from config import gkey

# %%
nfl_data = pd.read_excel("Resources/Draft_Players.xlsx")
nfl_data
# Out:
#      Round  Pick Team                Player        First       Last Position  \
# 0        1     1  HOU        Mario Williams        Mario   Williams       DE
# 1        1     2  NOR           Reggie Bush       Reggie       Bush       RB
# 2        1     3  TEN           Vince Young        Vince      Young       QB
# 3        1     4  NYJ  DBrickashaw Ferguson  DBrickashaw   Ferguson        T
# 4        1     5  GNB               AJ Hawk           AJ       Hawk       LB
# ..     ...   ...  ...                   ...          ...        ...      ...
# 250      7   251  HOU        David Anderson        David   Anderson       WR
# 251      7   252  NOR       Marques Colston      Marques    Colston       WR
# 252      7   253  GNB        Dave Tollefson         Dave  Tollefson       DE
# 253      7   254  SFO        Vickiel Vaughn      Vickiel     Vaughn       DB
# 254      7   255  OAK         Kevin McMahan        Kevin    McMahan       WR
#
#       Age   Until  AP1  ...  RushAtt  RushYards  RushTDs  Rec  RecYards  \
# 0    21.0  2016.0    1  ...        0          0        0    0         0
# 1    21.0  2016.0    0  ...     1286       5490       36  477      3598
# 2    23.0  2011.0    0  ...      282       1459       12    0         0
# 3    22.0  2015.0    0  ...        0          0        0    0         0
# 4    22.0  2016.0    0  ...        0          0        0    0         0
# ..    ...     ...  ...  ...      ...        ...      ...  ...       ...
# 250  23.0  2011.0    0  ...        0          0        0   88       965
# 251  23.0  2015.0    0  ...        2          7        0  711      9759
# 252  24.0  2012.0    0  ...        0          0        0    0         0
# 253   NaN     NaN    0  ...        0          0        0    0         0
# 254   NaN     NaN    0  ...        0          0        0    0         0
#
#      RecTDs  TackleSolo  DefensiveInt  Sacks             College
# 0         0         317             0   97.5  North Carolina St.
# 1        18           0             0    0.0                 USC
# 2         0           0             0    0.0               Texas
# 3         0           0             0    0.0            Virginia
# 4         0         645             9   20.0            Ohio St.
# ..      ...         ...           ...    ...                 ...
# 250       4           8             0    0.0        Colorado St.
# 251      72           1             0    0.0             Hofstra
# 252       0          62             0   10.5     NW Missouri St.
# 253       0           0             0    0.0            Arkansas
# 254       0           0             0    0.0               Maine
#
# [255 rows x 30 columns]

# %%
i = 0
target_search = nfl_data["College"][i]
url1 = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input="
url2 = "&inputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=AIzaSyDHFu3w7yoyFjwb8jZzc6A0isZpHJExctA"

search_url = url1 + str(target_search) + url2

# run a request using our params dictionary
response = requests.get(search_url)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=North%20Carolina%20St.&inputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=AIzaSyDHFu3w7yoyFjwb8jZzc6A0isZpHJExctA

# %%
# convert response to json
college_data = response.json()

# Print the json (pretty printed)
print(json.dumps(college_data, indent=4, sort_keys=True))
# Out:
# {
#     "candidates": [
#         {
#             "formatted_address": "Raleigh, NC 27695, United States",
#             "geometry": {
#                 "location": {
#                     "lat": 35.7846633,
#                     "lng": -78.6820946
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.80127854999999,
#                         "lng": -78.66176255
#                     },
#                     "southwest": {
#                         "lat": 35.75259755,
#                         "lng": -78.69418275
#                     }
#                 }
#             },
#             "name": "North Carolina State University",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115976847211996837305\">Michael K</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAX62ptIfSFnfJgM25nUdJK7bVmgBZxd-90xrSr_xazMmO00Y6QJ0SUyzOJHzWLfaS68KfIPQDCEF2Hx5JvPOjYm9LZ08hBbAwCxo4jUdhuhGy1zTUZQ6USkZKdGD8eNFjEhB2N3nfBsygkMkdy3-8a1iCGhR_C96e97cnWZotqGw6-diZtw2DMw",
#                     "width": 3024
#                 }
#             ],
#             "rating": 4.5
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the college info

print(college_data["candidates"][0]["name"])
print(college_data["candidates"][0]["formatted_address"])
print(college_data["candidates"][0]["geometry"]["location"]["lat"])
print(college_data["candidates"][0]["geometry"]["location"]["lng"])
# Out:
# North Carolina State University
# Raleigh, NC 27695, United States
# 35.7846633
# -78.6820946

# %%
# base url, params & containers

url1 = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input="
url2 = "&inputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=AIzaSyDHFu3w7yoyFjwb8jZzc6A0isZpHJExctA"

location = []
i=0

#loop through all the cities from the imported dataset .loc[i,4] .loc[i,5]
for  i in range(len(nfl_data)):
    
    #i = i + 1
    target_search = nfl_data["College"][i]
    search_url = url1 + str(target_search) + url2

    # run a request using our params dictionary
    response = requests.get(search_url).json()
    #pprint(response)
    try:
        
        #append to lists
        #athlete = nfl_data["Player"][i]
        name = response['candidates'][0]['name']
        addy = response['candidates'][0]['formatted_address']
        lat = response["candidates"][0]["geometry"]["location"]["lat"]
        lng = response["candidates"][0]["geometry"]["location"]["lng"]
        #hotel_df.append([hotel_name, address])
        #print(hotel,vicinity)
    
        location.append([name, addy, lat, lng])
        print(f" {name},{addy}, {lat}, {lng}")
        time.sleep(.2)
        
    except Exception:
        #print city name that was not found
        #location.append('NaN')
        #lat.append('NaN')
        #lon.append('NaN')
        print(f"{i}")
# Out:
#  North Carolina State University,Raleigh, NC 27695, United States, 35.7846633, -78.6820946
# 0
#  University of Southern California,Los Angeles, CA 90007, United States, 34.0223519, -118.285117
# 1
#  Texas,Texas, USA, 31.9685988, -99.9018131
# 2
#  Virginia,Virginia, USA, 37.4315734, -78.6568942
# 3
#  The Ohio State University,Columbus, OH 43210, United States, 40.0068363, -83.0306222
# 4
#  Maryland,Maryland, USA, 39.0457549, -76.64127119999999
# 5
#  Texas,Texas, USA, 31.9685988, -99.9018131
# 6
#  The Ohio State University,Columbus, OH 43210, United States, 40.0068363, -83.0306222
# 7
#  Florida State University,210 Fsu Campus, Tallahassee, FL 32306, United States, 30.439276, -84.3039455
# 8
#  University of Southern California,Los Angeles, CA 90007, United States, 34.0223519, -118.285117
# 9
#  Vanderbilt University,2201 West End Ave, Nashville, TN 37235, United States, 36.1447034, -86.8026551
# 10
#  Oregon,Oregon, USA, 43.8041334, -120.5542012
# 11
#  Florida State University,210 Fsu Campus, Tallahassee, FL 32306, United States, 30.439276, -84.3039455
# 12
#  Florida State University,210 Fsu Campus, Tallahassee, FL 32306, United States, 30.439276, -84.3039455
# 13
#  Clemson University,105 Sikes Hall, Clemson, SC 29634, United States, 34.6738437, -82.8368654
# 14
#  Tennessee,Tennessee, USA, 35.5174913, -86.5804473
# 15
#  Iowa,Iowa, USA, 41.8780025, -93.097702
# 16
#  The Ohio State University,Columbus, OH 43210, United States, 40.0068363, -83.0306222
# 17
#  Florida State University,210 Fsu Campus, Tallahassee, FL 32306, United States, 30.439276, -84.3039455
# 18
#  Penn State University,State College, PA 16801, United States, 40.7982133, -77.8599084
# 19
#  Minnesota,Minnesota, USA, 46.729553, -94.6858998
# 20
#  North Carolina State University,Raleigh, NC 27695, United States, 35.7846633, -78.6820946
# 21
#  Oklahoma City,Oklahoma City, OK, USA, 35.4675602, -97.5164276
# 22
#  South Carolina,South Carolina, USA, 33.836081, -81.1637245
# 23
#  The Ohio State University,Columbus, OH 43210, United States, 40.0068363, -83.0306222
# 24
#  North Carolina State University,Raleigh, NC 27695, United States, 35.7846633, -78.6820946
# 25
#  Memphis,Memphis, TN, USA, 35.1495343, -90.0489801
# 26
#  University of California, Los Angeles,Los Angeles, CA 90095, United States, 34.068921, -118.4451811
# 27
#  The Ohio State University,Columbus, OH 43210, United States, 40.0068363, -83.0306222
# 28
#  Louisiana State University,Baton Rouge, LA 70803, United States, 30.4132579, -91.1800023
# 29
#  Miami,Miami, FL, USA, 25.7616798, -80.1917902
# 30
#  Boston College,140 Commonwealth Avenue, Chestnut Hill, MA 02467, United States, 42.3355488, -71.16849450000001
# 31
#  Alabama,Alabama, USA, 32.3182314, -86.902298
# 32
#  Maryland,Maryland, USA, 39.0457549, -76.64127119999999
# 33
#  Miami,Miami, FL, USA, 25.7616798, -80.1917902
#
#  Virginia Polytechnic Institute and State University,Blacksburg, VA 24061, United States, 37.22838429999999, -80.42341669999999
# 221
#  Georgia,Georgia, USA, 32.1656221, -82.9000751
# 222
#  Texas Tech University,2500 Broadway, Lubbock, TX 79409, United States, 33.5842591, -101.8782822
# 223
#  North Carolina,North Carolina, USA, 35.7595731, -79.01929969999999
# 224
#  Texas,Texas, USA, 31.9685988, -99.9018131
# 225
#  Virginia Polytechnic Institute and State University,Blacksburg, VA 24061, United States, 37.22838429999999, -80.42341669999999
# 226
#  University of California, Los Angeles,Los Angeles, CA 90095, United States, 34.068921, -118.4451811
# 227
#  Baylor University,1311 S 5th St, Waco, TX 76706, United States, 31.5469132, -97.1210998
# 228
#  Arizona,Arizona, USA, 34.0489281, -111.0937311
# 229
#  Louisiana State University,Baton Rouge, LA 70803, United States, 30.4132579, -91.1800023
# 230
#  Maryland,Maryland, USA, 39.0457549, -76.64127119999999
# 231
#  Auburn,Auburn, AL, USA, 32.6098566, -85.48078249999999
# 232
#  Virginia Polytechnic Institute and State University,Blacksburg, VA 24061, United States, 37.22838429999999, -80.42341669999999
# 233
#  Oregon,Oregon, USA, 43.8041334, -120.5542012
# 234
#  Florida,Florida, USA, 27.6648274, -81.5157535
# 235
#  Auburn,Auburn, AL, USA, 32.6098566, -85.48078249999999
# 236
#  Stanford University,450 Serra Mall, Stanford, CA 94305, United States, 37.4274745, -122.169719
# 237
#  Wake Forest University,1834 Wake Forest Rd, Winston-Salem, NC 27109, United States, 36.1355052, -80.2791958
# 238
#  Virginia Polytechnic Institute and State University,Blacksburg, VA 24061, United States, 37.22838429999999, -80.42341669999999
# 239
#  Clemson University,105 Sikes Hall, Clemson, SC 29634, United States, 34.6738437, -82.8368654
# 240
#  Minnesota,Minnesota, USA, 46.729553, -94.6858998
# 241
#  Missouri,Missouri, USA, 37.9642529, -91.8318334
# 242
#  Michigan,Michigan, USA, 44.3148443, -85.60236429999999
# 243
#  Utah,Utah, USA, 39.3209801, -111.0937311
# 244
#  Utah,Utah, USA, 39.3209801, -111.0937311
# 245
#  Tulane University,6823 St Charles Ave, New Orleans, LA 70118, United States, 29.9407282, -90.12031669999999
# 246
#  California,California, USA, 36.778261, -119.4179324
# 247
#  Auburn,Auburn, AL, USA, 32.6098566, -85.48078249999999
# 248
#  Tennessee,Tennessee, USA, 35.5174913, -86.5804473
# 249
#  Chandler Bl & Colorado St,Chandler, AZ 85225, United States, 33.3060532, -111.8384626
# 250
#  Hofstra University,1000 Hempstead Turnpike, Hempstead, NY 11549, United States, 40.7166872, -73.5993965
# 251
#  Northwest Missouri State University,800 University Dr, Maryville, MO 64468, United States, 40.3519854, -94.8825243
# 252
#  Arkansas,Arkansas, USA, 35.20105, -91.8318334
# 253
#  Maine,Maine, USA, 45.253783, -69.4454689
# 254

# %%
colleges = pd.DataFrame(location)
colleges
# Out:
#                                        0  \
# 0        North Carolina State University
# 1      University of Southern California
# 2                                  Texas
# 3                               Virginia
# 4              The Ohio State University
# ..                                   ...
# 249            Chandler Bl & Colorado St
# 250                   Hofstra University
# 251  Northwest Missouri State University
# 252                             Arkansas
# 253                                Maine
#
#                                                      1          2           3
# 0                     Raleigh, NC 27695, United States  35.784663  -78.682095
# 1                 Los Angeles, CA 90007, United States  34.022352 -118.285117
# 2                                           Texas, USA  31.968599  -99.901813
# 3                                        Virginia, USA  37.431573  -78.656894
# 4                    Columbus, OH 43210, United States  40.006836  -83.030622
# ..                                                 ...        ...         ...
# 249                  Chandler, AZ 85225, United States  33.306053 -111.838463
# 250  1000 Hempstead Turnpike, Hempstead, NY 11549, ...  40.716687  -73.599396
# 251  800 University Dr, Maryville, MO 64468, United...  40.351985  -94.882524
# 252                                      Arkansas, USA  35.201050  -91.831833
# 253                                         Maine, USA  45.253783  -69.445469
#
# [254 rows x 4 columns]

# %%
colleges.columns=["name", "address", "lat", "lng"]
#colleges.set_index(["name"], inplace=True)
colleges
# Out:
#                                     name  \
# 0        North Carolina State University
# 1      University of Southern California
# 2                                  Texas
# 3                               Virginia
# 4              The Ohio State University
# ..                                   ...
# 249            Chandler Bl & Colorado St
# 250                   Hofstra University
# 251  Northwest Missouri State University
# 252                             Arkansas
# 253                                Maine
#
#                                                address        lat         lng
# 0                     Raleigh, NC 27695, United States  35.784663  -78.682095
# 1                 Los Angeles, CA 90007, United States  34.022352 -118.285117
# 2                                           Texas, USA  31.968599  -99.901813
# 3                                        Virginia, USA  37.431573  -78.656894
# 4                    Columbus, OH 43210, United States  40.006836  -83.030622
# ..                                                 ...        ...         ...
# 249                  Chandler, AZ 85225, United States  33.306053 -111.838463
# 250  1000 Hempstead Turnpike, Hempstead, NY 11549, ...  40.716687  -73.599396
# 251  800 University Dr, Maryville, MO 64468, United...  40.351985  -94.882524
# 252                                      Arkansas, USA  35.201050  -91.831833
# 253                                         Maine, USA  45.253783  -69.445469
#
# [254 rows x 4 columns]

# %%
#colleges.to_json('colleges.json', orient="split")

# %%
#cast types
colleges['lat'] = colleges['lat'].astype(float)
colleges['lng'] = colleges['lng'].astype(float)
colleges['address'] = colleges['address'].str.title()
colleges['name'] = colleges['name'].str.title()

# %%
# value counts
# what is the distribution of issue types?
colleges.groupby('name').count()
# Out:
#                               address  lat  lng
# name
# 7Th St & Michigan Av                3    3    3
# Abilene Christian University        1    1    1
# Akron                               1    1    1
# Alabama                             5    5    5
# Alabama State University            1    1    1
# ...                               ...  ...  ...
# Wake Forest University              1    1    1
# Washington                          1    1    1
# West Virginia                       1    1    1
# Wisconsin                           5    5    5
# Wyoming                             1    1    1
#
# [95 rows x 3 columns]

# %%
def colleges_to_geojson(colleges, properties, lat='lat', lon='lng'):
    """
    Turn a dataframe containing point data into a geojson formatted python dictionary
    
    df : the dataframe to convert to geojson
    properties : a list of columns in the dataframe to turn into geojson feature properties
    lat : the name of the column in the dataframe that contains latitude data
    lon : the name of the column in the dataframe that contains longitude data
    """
    
    # create a new python dict to contain our geojson data, using geojson format
    geojson = {'type':'FeatureCollection', 'features':[]}

    # loop through each row in the dataframe and convert each row to geojson format
    for _, row in colleges.iterrows():
        # create a feature template to fill in
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}

        # fill in the coordinates
        feature['geometry']['coordinates'] = [row[lon],row[lat]]

        # for each column, get the value and add it as a new feature property
        for prop in properties:
            feature['properties'][prop] = row[prop]
        
        # add this feature (aka, converted dataframe row) to the list of features inside our dict
        geojson['features'].append(feature)
    
    return geojson

# %%
useful_columns = ['name','address', 'lat', 'lng']
geojson_dict = colleges_to_geojson(colleges, properties=useful_columns)
geojson_str = json.dumps(geojson_dict, indent=2)

# %%
# save the geojson result to a file
output_filename = 'collegeDataset.json'
with open(output_filename, 'w') as output_file:
    output_file.write('var dataset = {};'.format(geojson_str))
    
# how many features did we save to the geojson file?
print('{} geotagged features saved to file'.format(len(geojson_dict['features'])))
# Out:
# 254 geotagged features saved to file

# %%
colleges.to_csv('colleges.csv')
